# %% [markdown]
# # CocaCola prices
# Forecast the CocaCola prices and Airlines Passengers data set. Prepare a document for each model explaining
# how many dummy variables you have created
# and RMSE value for each model. Finally which model you will use for
# Forecasting.

# %%
# Import the file
import pandas as pd

Cocacola = pd.read_excel("D:/Shiva Data Science/ExcelR Assignments/Forecasting/CocaCola_Sales_Rawdata.xlsx")
Cocacola
# Out:
#    Quarter        Sales
# 0    Q1_86  1734.827000
# 1    Q2_86  2244.960999
# 2    Q3_86  2533.804993
# 3    Q4_86  2154.962997
# 4    Q1_87  1547.818996
# 5    Q2_87  2104.411995
# 6    Q3_87  2014.362999
# 7    Q4_87  1991.746998
# 8    Q1_88  1869.049999
# 9    Q2_88  2313.631996
# 10   Q3_88  2128.320000
# 11   Q4_88  2026.828999
# 12   Q1_89  1910.603996
# 13   Q2_89  2331.164993
# 14   Q3_89  2206.549995
# 15   Q4_89  2173.967995
# 16   Q1_90  2148.278000
# 17   Q2_90  2739.307999
# 18   Q3_90  2792.753998
# 19   Q4_90  2556.009995
# 20   Q1_91  2480.973999
# 21   Q2_91  3039.522995
# 22   Q3_91  3172.115997
# 23   Q4_91  2879.000999
# 24   Q1_92  2772.000000
# 25   Q2_92  3550.000000
# 26   Q3_92  3508.000000
# 27   Q4_92  3243.859993
# 28   Q1_93  3056.000000
# 29   Q2_93  3899.000000
# 30   Q3_93  3629.000000
# 31   Q4_93  3373.000000
# 32   Q1_94  3352.000000
# 33   Q2_94  4342.000000
# 34   Q3_94  4461.000000
# 35   Q4_94  4017.000000
# 36   Q1_95  3854.000000
# ...

# %%
import matplotlib.pyplot as plt
Cocacola.Sales.plot()
# Out:
# <Axes: >

# %%
# Data preprocessing / Creating Dummy Variables

## Same as encoder
import numpy as np

Quaters =['Q1','Q2','Q3','Q4']

p = Cocacola["Quarter"][0]
p[0:2]
Cocacola["quarter"]=0
Cocacola["Year"]=0

for i in range(42):
    p = Cocacola["Quarter"][i]
    Cocacola['quarter'][i]= p[0:2]
    
for i in range(42):
    p = Cocacola["Quarter"][i]
    Cocacola['Year'][i]= p[3:]

month_dummies = pd.DataFrame(pd.get_dummies(Cocacola['quarter']))
month_dummies


Cocacola1 = pd.concat([Cocacola,month_dummies],axis = 1)
Cocacola1
# Out:
# C:\Users\91879\AppData\Local\Temp\ipykernel_7896\17740956.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Cocacola['quarter'][i]= p[0:2]
# C:\Users\91879\AppData\Local\Temp\ipykernel_7896\17740956.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Cocacola['Year'][i]= p[3:]
#    Quarter        Sales quarter Year  Q1  Q2  Q3  Q4
# 0    Q1_86  1734.827000      Q1   86   1   0   0   0
# 1    Q2_86  2244.960999      Q2   86   0   1   0   0
# 2    Q3_86  2533.804993      Q3   86   0   0   1   0
# 3    Q4_86  2154.962997      Q4   86   0   0   0   1
# 4    Q1_87  1547.818996      Q1   87   1   0   0   0
# ...

# %%
import numpy as np
Cocacola1["t"] = np.arange(1,43)

Cocacola1["t_squared"] =Cocacola1["t"]*Cocacola1["t"]

Cocacola1["log_Sales"] = np.log(Cocacola1["Sales"])

Cocacola1.columns
Cocacola1.Sales.plot()
Cocacola1
# Out:
#    Quarter        Sales quarter Year  Q1  Q2  Q3  Q4   t  t_squared  log_Sales
# 0    Q1_86  1734.827000      Q1   86   1   0   0   0   1          1   7.458663
# 1    Q2_86  2244.960999      Q2   86   0   1   0   0   2          4   7.716443
# 2    Q3_86  2533.804993      Q3   86   0   0   1   0   3          9   7.837477
# 3    Q4_86  2154.962997      Q4   86   0   0   0   1   4         16   7.675529
# 4    Q1_87  1547.818996      Q1   87   1   0   0   0   5         25   7.344602
# 5    Q2_87  2104.411995      Q2   87   0   1   0   0   6         36   7.651791
# 6    Q3_87  2014.362999      Q3   87   0   0   1   0   7         49   7.608058
# 7    Q4_87  1991.746998      Q4   87   0   0   0   1   8         64   7.596767
# 8    Q1_88  1869.049999      Q1   88   1   0   0   0   9         81   7.533186
# 9    Q2_88  2313.631996      Q2   88   0   1   0   0  10        100   7.746574
# 10   Q3_88  2128.320000      Q3   88   0   0   1   0  11        121   7.663088
# ...

# %%
# EDA
import seaborn as sns

# Heat Map
plt.figure(figsize=(12,8))
heatmap_y_Quarter = pd.pivot_table(data=Cocacola1,values="Sales",index="Year",columns="quarter",aggfunc="mean",fill_value=0)
sns.heatmap(heatmap_y_Quarter,annot=True,fmt="g") #fmt is format of the grid values
# Out:
# <Axes: xlabel='quarter', ylabel='Year'>

# %%
#Histogram
Cocacola1.Sales.hist()
# Out:
# <Axes: >

# %%
#Density plot and Lag plot
Cocacola1.Sales.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
# scatter plot
from pandas.plotting import lag_plot
lag_plot(Cocacola1.Sales)
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 1)'>

# %%
# create an autocorrelation plot
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(Cocacola1.Sales,lags=40)

# %%
# Box plot for every

plt.figure(figsize=(8,6))
plt.subplot(211)
sns.boxplot(x="quarter", y="Sales" ,data = Cocacola1)

plt.subplot(212)
sns.boxplot(x="Year", y="Sales" ,data = Cocacola1)
# Out:
# <Axes: xlabel='Year', ylabel='Sales'>

# %%
# Line plot
plt.figure(figsize=(12,3))
sns.lineplot(x="quarter" ,y="Sales", data=Cocacola1)
# Out:
# <Axes: xlabel='quarter', ylabel='Sales'>

# %% [markdown]
# ## Splitting data

# %%
Train = Cocacola1.head(int(len(Cocacola1.quarter)*0.9))
Test = Cocacola1.tail(len(Cocacola1.quarter)-(len(Train.quarter)))
Train
# Out:
#    Quarter        Sales quarter Year  Q1  Q2  Q3  Q4   t  t_squared  log_Sales
# 0    Q1_86  1734.827000      Q1   86   1   0   0   0   1          1   7.458663
# 1    Q2_86  2244.960999      Q2   86   0   1   0   0   2          4   7.716443
# 2    Q3_86  2533.804993      Q3   86   0   0   1   0   3          9   7.837477
# 3    Q4_86  2154.962997      Q4   86   0   0   0   1   4         16   7.675529
# 4    Q1_87  1547.818996      Q1   87   1   0   0   0   5         25   7.344602
# 5    Q2_87  2104.411995      Q2   87   0   1   0   0   6         36   7.651791
# 6    Q3_87  2014.362999      Q3   87   0   0   1   0   7         49   7.608058
# 7    Q4_87  1991.746998      Q4   87   0   0   0   1   8         64   7.596767
# 8    Q1_88  1869.049999      Q1   88   1   0   0   0   9         81   7.533186
# 9    Q2_88  2313.631996      Q2   88   0   1   0   0  10        100   7.746574
# 10   Q3_88  2128.320000      Q3   88   0   0   1   0  11        121   7.663088
# ...

# %%
Test
# Out:
#    Quarter   Sales quarter Year  Q1  Q2  Q3  Q4   t  t_squared  log_Sales
# 37   Q2_95  4936.0      Q2   95   0   1   0   0  38       1444   8.504311
# 38   Q3_95  4895.0      Q3   95   0   0   1   0  39       1521   8.495970
# 39   Q4_95  4333.0      Q4   95   0   0   0   1  40       1600   8.374015
# 40   Q1_96  4194.0      Q1   96   1   0   0   0  41       1681   8.341410
# 41   Q2_96  5253.0      Q2   96   0   1   0   0  42       1764   8.566555

# %%
# Linear model
import statsmodels.formula.api as smf

linear_model = smf.ols("Sales~t",data=Train).fit()
pred_linear = pd.Series(linear_model.predict(pd.DataFrame(Test["t"])))
rmse_linear = np.sqrt(np.mean(np.array(Test["Sales"]-np.array(pred_linear))**2))
rmse_linear
# Out:
# 737.1568992951978

# %%
#Exponential

linear_model = smf.ols("log_Sales~t",data=Train).fit()
pred_Exp = pd.Series(linear_model.predict(pd.DataFrame(Test["t"])))
rmse_Exp = np.sqrt(np.mean(np.array(Test["Sales"]-np.array(pred_Exp))**2))
rmse_Exp
# Out:
# 4730.513510904965

# %%
#Quadratic 

Quad = smf.ols('Sales~t+t_squared',data=Train).fit()
pred_Quad = pd.Series(Quad.predict(Test[["t","t_squared"]]))
rmse_Quad = np.sqrt(np.mean((np.array(Test['Sales'])-np.array(pred_Quad))**2))
rmse_Quad
# Out:
# 445.8029895177931

# %%
#Additive seasonality 

add_sea = smf.ols('Sales~Q1+Q2+Q3+Q4',data=Train).fit()
pred_add_sea = pd.Series(add_sea.predict(Test[['Q1','Q2','Q3','Q4']]))
rmse_add_sea = np.sqrt(np.mean((np.array(Test['Sales'])-np.array(pred_add_sea))**2))
rmse_add_sea
# Out:
# 1931.3627904063203

# %%
#Additive Seasonality Quadratic 

add_sea_Quad = smf.ols('Sales~t+t_squared+Q1+Q2+Q3+Q4',data=Train).fit()
pred_add_sea_quad = pd.Series(add_sea_Quad.predict(Test[['Q1','Q2','Q3','Q4','t','t_squared']]))
rmse_add_sea_quad = np.sqrt(np.mean((np.array(Test['Sales'])-np.array(pred_add_sea_quad))**2))
rmse_add_sea_quad
# Out:
# 252.25576081762068

# %%
##Multiplicative Seasonality

Mul_sea = smf.ols('log_Sales~Q1+Q2+Q3+Q4',data = Train).fit()
pred_Mult_sea = pd.Series(Mul_sea.predict(Test))
rmse_Mult_sea = np.sqrt(np.mean((np.array(Test['Sales'])-np.array(np.exp(pred_Mult_sea)))**2))
rmse_Mult_sea
# Out:
# 2023.7328645103632

# %%
#Multiplicative Additive Seasonality 

Mul_Add_sea = smf.ols('log_Sales~t+Q1+Q2+Q3+Q4',data = Train).fit()
pred_Mult_add_sea = pd.Series(Mul_Add_sea.predict(Test))
rmse_Mult_add_sea = np.sqrt(np.mean((np.array(Test['Sales'])-np.array(np.exp(pred_Mult_add_sea)))**2))
rmse_Mult_add_sea
# Out:
# 290.2684788886517

# %%
#Compare the results 

data = {"MODEL":pd.Series(["rmse_linear","rmse_Exp","rmse_Quad","rmse_add_sea","rmse_add_sea_quad","rmse_Mult_sea","rmse_Mult_add_sea"]),"RMSE_Values":pd.Series([rmse_linear,rmse_Exp,rmse_Quad,rmse_add_sea,rmse_add_sea_quad,rmse_Mult_sea,rmse_Mult_add_sea])}
table_rmse=pd.DataFrame(data)
table_rmse.sort_values(['RMSE_Values'])
# Out:
#                MODEL  RMSE_Values
# 4  rmse_add_sea_quad   252.255761
# 6  rmse_Mult_add_sea   290.268479
# 2          rmse_Quad   445.802990
# 0        rmse_linear   737.156899
# 3       rmse_add_sea  1931.362790
# 5      rmse_Mult_sea  2023.732865
# 1           rmse_Exp  4730.513511

# %% [markdown]
# # Model "Additive Seasonality Quadratic" is best for the Forecasting
